# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt

from pathlib import Path

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/gaby/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csv_path = Path("Resources/whale_returns.csv")

whale_df = pd.read_csv(csv_path, index_col='Date', parse_dates=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale_df.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# 2015-03-09                      False               False
# 2015-03-10                      False               False
# 2015-03-11                      False               False
# 2015-03-12                      False               False
# 2015-03-13                      False               False
# 2015-03-16                      False               False
# 2015-03-17                      False               False
# 2015-03-18                      False               False
# 2015-03-19                      False               False
# 2015-03-20                      False               False
# 2015-03-23                      False               False
# 2015-03-24                      False               False
# 2015-03-25                      False               False
# 2015-03-26                      False               False
# 2015-03-27                      False               False
# 2015-03-30                      False               False
# 2015-03-31                      False               False
# 2015-04-01                      False               False
# 2015-04-02                      False               False
# 2015-04-06                      False               False
# 2015-04-07                      False               False
# 2015-04-08                      False               False
# 2015-04-09                      False               False
# 2015-04-10                      False               False
# 2015-04-13                      False               False
# ...                               ...                 ...
# 2019-03-20                      False               False
# 2019-03-21                      False               False
# 2019-03-22                      False               False
# 2019-03-25                      False               False
# 2019-03-26                      False               False
# 2019-03-27                      False               False
# 2019-03-28                      False               False
# 2019-03-29                      False               False
# 2019-04-01                      False               False
# 2019-04-02                      False               False
# 2019-04-03                      False               False
# 2019-04-04                      False               False
# 2019-04-05                      False               False
# 2019-04-08                      False               False
# 2019-04-09                      False               False
# 2019-04-10                      False               False
# 2019-04-11                      False               False
# 2019-04-12                      False               False
# 2019-04-15                      False               False
# 2019-04-16                      False               False
# 2019-04-17                      False               False
# 2019-04-18                      False               False
# 2019-04-22                      False               False
# 2019-04-23                      False               False
# 2019-04-24                      False               False
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# 2015-03-04                        False                   False
# 2015-03-05                        False                   False
# 2015-03-06                        False                   False
# 2015-03-09                        False                   False
# 2015-03-10                        False                   False
# 2015-03-11                        False                   False
# 2015-03-12                        False                   False
# 2015-03-13                        False                   False
# 2015-03-16                        False                   False
# 2015-03-17                        False                   False
# 2015-03-18                        False                   False
# 2015-03-19                        False                   False
# 2015-03-20                        False                   False
# 2015-03-23                        False                   False
# 2015-03-24                        False                   False
# 2015-03-25                        False                   False
# 2015-03-26                        False                   False
# 2015-03-27                        False                   False
# 2015-03-30                        False                   False
# 2015-03-31                        False                   False
# 2015-04-01                        False                   False
# 2015-04-02                        False                   False
# 2015-04-06                        False                   False
# 2015-04-07                        False                   False
# 2015-04-08                        False                   False
# 2015-04-09                        False                   False
# 2015-04-10                        False                   False
# 2015-04-13                        False                   False
# ...                                 ...                     ...
# 2019-03-20                        False                   False
# 2019-03-27  0.008395 -0.004457
# 2019-03-28  0.009932  0.005775
# 2019-03-29 -0.000868  0.004576
# 2019-04-01  0.008159  0.007257
# 2019-04-02  0.003776 -0.000413
# 2019-04-03 -0.003337  0.000287
# 2019-04-04 -0.003597  0.003265
# 2019-04-05  0.001519  0.009306
# 2019-04-08  0.003761  0.000218
# 2019-04-09  0.012012 -0.011639
# 2019-04-10 -0.004221  0.009632
# 2019-04-11  0.001705 -0.001568
# 2019-04-12 -0.005501  0.004504
# 2019-04-15 -0.004331 -0.004572
# 2019-04-16 -0.006945  0.002899
# 2019-04-17 -0.010301 -0.005228
# 2019-04-18 -0.000588 -0.001229
# 2019-04-22  0.000677 -0.001936
# 2019-04-23  0.004969  0.009622
# 2019-04-24  0.001095  0.000399
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csv_path = Path("Resources/sp500_history.csv")
sp500history_df = pd.read_csv(csv_path, index_col='Date', parse_dates=True)
sp500history_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500history_df["Close"] = sp500history_df["Close"].str.replace("$", " ")
sp500history_df["Close"] = sp500history_df["Close"].astype('float')
sp500history_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500history_df["Close"] = sp500history_df["Close"].pct_change()
sp500history_df
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# 2019-04-12  0.000630
# 2019-04-11 -0.006566
# 2019-04-10 -0.000038
# 2019-04-09 -0.003466
# 2019-04-08  0.006105
# 2019-04-05 -0.001046
# 2019-04-04 -0.004615
# 2019-04-03 -0.002080
# 2019-04-02 -0.002144
# 2019-04-01 -0.000017
# 2019-03-29 -0.011436
# 2019-03-28 -0.006689
# 2019-03-27 -0.003577
# 2019-03-26  0.004666
# 2019-03-25 -0.007132
# 2019-03-22  0.000840
# 2019-03-21  0.019342
# 2019-03-20 -0.010736
# 2019-03-19  0.002953
# 2019-03-18  0.000131
# 2019-03-15 -0.003692
# 2019-03-14 -0.004960
# 2019-03-13  0.000869
# 2019-03-12 -0.006902
# ...              ...
# 2012-11-13  0.014047
# 2012-11-12  0.004001
# 2012-11-09 -0.000130
# 2012-11-08 -0.001696
# 2012-11-07  0.012356
# 2012-11-06  0.024281
# 2012-11-05 -0.007792
# 2012-11-02 -0.002159
# 2012-11-01  0.009468
# 2012-10-31 -0.010808
# 2012-10-26 -0.000156
# 2012-10-25  0.000729
# 2012-10-24 -0.002987
# 2012-10-23  0.003095
# 2012-10-22  0.014656
# 2012-10-19 -0.000439
# 2012-10-18  0.016851
# 2012-10-17  0.002450
# 2012-10-16 -0.004100
# 2012-10-15 -0.010166
# 2012-10-12 -0.008013
# 2012-10-11  0.002975
# 2012-10-10 -0.000195
# 2012-10-09  0.006227
# 2012-10-08  0.009990
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp500history_df.dropna(inplace=True)

# %%
# Rename `Close` Column to be specific to this portfolio.

sp500history_df.rename(columns={'Close': 'S&P 500'}, inplace=True)
sp500history_df
# Out:
#              S&P 500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# 2015-03-06 -0.011460 -0.003929
# 2015-03-09  0.001303  0.017254
# 2015-03-10 -0.012155  0.001921
# 2015-03-11  0.000605 -0.012445
# 2015-03-12  0.011667  0.006112
# 2015-03-13 -0.005062 -0.013353
# 2015-03-16  0.004117  0.003331
# 2015-03-17  0.001274 -0.012012
# 2015-03-18  0.006269  0.004896
# 2015-03-19  0.000829 -0.008932
# 2015-03-20  0.004404  0.001749
# 2015-03-23  0.001519  0.006177
# 2015-03-24 -0.000885  0.014774
# 2015-03-25 -0.016862  0.002383
# 2015-03-26 -0.001979 -0.002363
# 2015-03-27  0.005187 -0.012089
# 2015-03-30  0.008232  0.008874
# 2015-03-31 -0.003281  0.003981
# 2015-04-01  0.003005 -0.003517
# 2015-04-02  0.004874 -0.006565
# 2015-04-06  0.006362  0.002066
# 2015-04-07 -0.002593 -0.002675
# 2015-04-08  0.003734 -0.004438
# 2015-04-09 -0.001346 -0.005176
# 2015-04-10  0.005076  0.004602
# 2015-04-13 -0.001441 -0.001627
# 2015-04-14  0.003274 -0.005122
# ...              ...       ...
# 2019-03-11  0.012871 -0.002945
# 2019-03-12  0.002797 -0.006902
# 2019-03-13  0.003847  0.000869
# 2019-03-14  0.007894 -0.004960
# 2019-03-15  0.003873 -0.003692
# 2019-03-18  0.013356  0.000131
# 2019-03-19 -0.000504  0.002953
# 2019-03-20  0.001009 -0.010736
# 2019-03-21  0.004714  0.019342
# 2019-03-22 -0.020949  0.000840
# 2019-03-25 -0.002058 -0.007132
# 2019-03-26  0.005614  0.004666
# 2019-03-27 -0.004457 -0.003577
# 2019-03-28  0.005775 -0.006689
# 2019-03-29  0.004576 -0.011436
# 2019-04-01  0.007257 -0.000017
# 2019-04-02 -0.000413 -0.002144
# 2019-04-03  0.000287 -0.002080
# 2019-04-04  0.003265 -0.004615
# 2019-04-05  0.009306 -0.001046
# 2019-04-08  0.000218  0.006105
# 2019-04-09 -0.011639 -0.003466
# 2019-04-10  0.009632 -0.000038
# 2019-04-11 -0.001568 -0.006566
# 2019-04-12  0.004504  0.000630
# 2019-04-15 -0.004572 -0.000509
# 2019-04-16  0.002899  0.002279
# 2019-04-17 -0.005228 -0.001577
# 2019-04-18 -0.001229 -0.001011
# 2019-04-22 -0.001936 -0.008764
#
# [1042 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Analysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_data.plot()

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_data).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20, 10), title='Culmulative Returns of all portfolios')

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_data.plot.box(figsize=(20, 10), title='Box Plot Graph of Portfolios')

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = combined_data.std()
daily_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = daily_std["S&P 500"]
sp500_std
# Determine which portfolios are riskier than the S&P 500
daily_std = daily_std.sort_values(ascending=False)
daily_std.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# S&P 500                        0.008587
# Algo 2                         0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# dtype: float64

# %%
sp500_std = daily_std["S&P 500"]
sp500_std
# Out:
# 0.00858688974707399

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std.sort_values(inplace=True)
annualized_std
# Out:
# PAULSON & CO.INC.              0.111527
# Algo 1                         0.121006
# SOROS FUND MANAGEMENT LLC      0.125348
# Algo 2                         0.132413
# S&P 500                        0.136313
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_data.rolling(window=21).std().plot(figsize=(20, 10), title='Rolling STD for Portfolios')
# Plot the rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
portfolio_corr = combined_data.corr()
# Display de correlation matrix
portfolio_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P 500                                       0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
# S&P 500                                        -0.001505
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# PAULSON & CO.INC.                          0.545451  0.268631  0.678085
# TIGER GLOBAL MANAGEMENT LLC                0.424125  0.164114  0.507160
# BERKSHIRE HATHAWAY INC                     1.000000  0.291678  0.687756
# Algo 1                                     0.291678  1.000000  0.287852
# Algo 2                                     0.687756  0.287852  1.000000
# S&P 500                                   -0.013856 -0.033963 -0.002192
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.000574
# PAULSON & CO.INC.            0.013549
# TIGER GLOBAL MANAGEMENT LLC -0.001505
# BERKSHIRE HATHAWAY INC      -0.013856
# Algo 1                      -0.033963
# Algo 2                      -0.002192
# S&P 500                      1.000000

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
bershire_covariance = combined_data['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_data['S&P 500'])
bershire_covariance
# Calculate variance of S&P 500
sp_500_variance = combined_data['S&P 500'].rolling(window=60).var()
sp_500_variance
# Computing beta
bershire_beta = bershire_covariance / sp_500_variance

bershire_beta
# Plot beta trend
bershire_beta.plot(figsize=(20, 10), title='Bershire Hathaway Inc Beta')

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm_coveriance = combined_data.ewm(halflife=21).mean()
ewm_coveriance.plot(figsize=(20, 10), title='Exponentially Weighted Average for 21-day half-life Portfolios')

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and their institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_data.mean() * 252) / (combined_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar', title ='Sharpe Ratios for Portfolios Bar Plot')

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
google_data = Path("Resources/goog_historical.csv")
google = pd.read_csv(
    google_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True
)
google.sort_index(inplace=True)
google.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Reading data from 2nd stock
appl_data = Path("Resources/aapl_historical.csv")
apple = pd.read_csv(
    appl_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True
)
apple.sort_index(inplace=True)
apple.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99

# %%
# Reading data from 3rd stock
costco_data = Path("Resources/cost_historical.csv")
costco = pd.read_csv(
    costco_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True
)
costco.sort_index(inplace=True)
costco.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60

# %%
# Combine all stocks in a single DataFrame
combined_stocks = pd.concat([google, apple, costco], axis="rows", join="inner")
combined_stocks.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Reset Date index
combined_stocks = combined_stocks.reset_index()
combined_stocks.head()
# Out:
#   Trade DATE Symbol     NOCP
# 0 2018-05-11   GOOG  1098.26
# 1 2018-05-14   GOOG  1100.20
# 2 2018-05-15   GOOG  1079.23
# 3 2018-05-16   GOOG  1081.77
# 4 2018-05-17   GOOG  1078.59

# %%
# Reorganize portfolio data by having a column per symbol
combined_stocks = combined_stocks.pivot_table(values='NOCP', index="Trade DATE", columns="Symbol")
combined_stocks.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns
stocks_daily_returns = combined_stocks.pct_change()
# Drop NAs
stocks_daily_returns.dropna(inplace=True)
# Display sample data
stocks_daily_returns.head()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = stocks_daily_returns.dot(weights)

# Display sample data
portfolio_returns.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %%
portfolio_returns.columns["Portfolio"]

myportfolio_df = pd.DataFrame(column = ['My Portfolio'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3757d7921366> in <module>
# ----> 1 portfolio_returns.columns["Portfolio"]
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
portfolio_returns.rename(columns={'My Portfolio'}, inplace=True)
portfolio_returns
#dictionary old name with new name

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

allportfolio_returns = pd.concat([cumulative_returns, portfolio_returns], axis="columns", join="inner")
allportfolio_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   1.108502            0.762662
# 2018-05-15                   1.107698            0.761588
# 2018-05-16                   1.117265            0.766344
# 2018-05-17                   1.115080            0.768278
# 2018-05-18                   1.110221            0.766225
# 2018-05-21                   1.113001            0.765309
# 2018-05-22                   1.110391            0.766202
# 2018-05-23                   1.109393            0.765698
# 2018-05-24                   1.106997            0.763991
# 2018-05-25                   1.109372            0.765641
# 2018-05-29                   1.097486            0.761581
# 2018-05-30                   1.102593            0.764727
# 2018-05-31                   1.093713            0.760113
# 2018-06-01                   1.099414            0.762974
# 2018-06-04                   1.105998            0.759641
# 2018-06-05                   1.106836            0.764942
# 2018-06-06                   1.118699            0.772527
# 2018-06-07                   1.117666            0.779630
# 2018-06-08                   1.119672            0.785715
# 2018-06-11                   1.125568            0.789277
# 2018-06-12                   1.131171            0.789618
# 2018-06-13                   1.124250            0.788942
# 2018-06-14                   1.129799            0.788911
# 2018-06-15                   1.127678            0.788417
# 2018-06-18                   1.128028            0.788210
# 2018-06-19                   1.124122            0.789678
# 2018-06-20                   1.129075            0.794175
# 2018-06-21                   1.122997            0.789812
# 2018-06-22                   1.126823            0.793735
# 2018-06-25                   1.110662            0.787998
# ...                               ...                 ...
# 2019-03-11                   1.113017            0.778285
# 2019-03-12                   1.112817            0.781020
# 2019-03-13                   1.115848            0.780181
# 2019-03-14                   1.115541            0.781705
# 2019-03-15                   1.119182            0.784791
# 2019-03-18                   1.126672            0.784584
# 2019-03-19                   1.126845            0.786184
# 2019-03-20                   1.121568            0.782668
# 2019-03-21                   1.138513            0.786383
# 2019-03-22                   1.118403            0.775611
# 2019-03-25                   1.114678            0.775285
# 2019-03-26                   1.119568            0.779659
# 2019-03-27                   1.115097            0.773951
# 2019-03-28                   1.118684            0.768561
# 2019-03-29                   1.120241            0.770890
# 2019-04-01                   1.130323            0.778655
# 2019-04-02                   1.130541            0.774280
# 2019-04-03                   1.134568            0.775290
# 2019-04-04                   1.135991            0.783531
# 2019-04-05                   1.143807            0.788612
# 2019-04-08                   1.144359            0.788367
# 2019-04-09                   1.137885            0.784901
# 2019-04-10                   1.149045            0.791468
# 2019-04-11                   1.152959            0.788335
# 2019-04-12                   1.159488            0.787417
# 2019-04-15                   1.157839            0.786506
# 2019-04-16                   1.160965            0.786811
# 2019-04-17                   1.157602            0.781723
# 2019-04-18                   1.159278            0.782678
# 2019-04-22                   1.156280            0.776939
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 
# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

daily_std = allportfolio_returns.std()
all_portfolios_annualized_std = daily_std * np.sqrt(252)
all_portfolios_annualized_std.sort_values(inplace=True)
all_portfolios_annualized_std
# Out:
# 0                              0.211627
# PAULSON & CO.INC.              0.363991
# S&P 500                        0.502456
# SOROS FUND MANAGEMENT LLC      0.738075
# Algo 2                         1.195839
# TIGER GLOBAL MANAGEMENT LLC    1.781699
# BERKSHIRE HATHAWAY INC         1.951776
# Algo 1                         2.697656
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation
allportfolio_returns.rolling(window=21).std().plot(figsize=(20, 10), title='Rolling STD for All Portfolios')

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
allportfolios_corr = allportfolio_returns.corr()
# Display de correlation matrix
allportfolios_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.770132
# PAULSON & CO.INC.                             0.770132            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.261663            0.480229
# BERKSHIRE HATHAWAY INC                        0.836400            0.451272
# Algo 1                                       -0.112991           -0.295214
# Algo 2                                        0.906356            0.778611
# S&P 500                                      -0.910142           -0.855482
# 0                                             0.169902            0.075793
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.261663
# PAULSON & CO.INC.                               0.480229
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.342220
# Algo 1                                         -0.894128
# Algo 2                                          0.549154
# S&P 500                                        -0.244808
# 0                                              -0.018270
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.836400 -0.112991  0.906356
# PAULSON & CO.INC.                          0.451272 -0.295214  0.778611
# TIGER GLOBAL MANAGEMENT LLC                0.342220 -0.894128  0.549154
# BERKSHIRE HATHAWAY INC                     1.000000 -0.289704  0.864615
# Algo 1                                    -0.289704  1.000000 -0.476984
# Algo 2                                     0.864615 -0.476984  1.000000
# S&P 500                                   -0.652109  0.124587 -0.854930
# 0                                          0.192974  0.060402  0.115036
#
#                               S&P 500         0
# SOROS FUND MANAGEMENT LLC   -0.910142  0.169902
# PAULSON & CO.INC.           -0.855482  0.075793
# TIGER GLOBAL MANAGEMENT LLC -0.244808 -0.018270
# BERKSHIRE HATHAWAY INC      -0.652109  0.192974
# Algo 1                       0.124587  0.060402
# Algo 2                      -0.854930  0.115036
# S&P 500                      1.000000 -0.147091
# 0                           -0.147091  1.000000

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
myportfolio_covariance = allportfolios_return['My Portfolio'].rolling(window=60).cov(combined_data['S&P 500'])
myportfolio_covariance
# Calculate variance of S&P 500
sp_500_variance = combined_data['S&P 500'].rolling(window=60).var()
sp_500_variance
# Computing beta
myportfolio_beta = myportfolio_covariance / sp_500_variance

myportfolio_beta
# Plot beta trend
myportfolio_beta.plot(figsize=(20, 10), title='My portfolio Beta')

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
allsharpe_ratios = (allportfolio_returns.mean() * 252) / (allportfolio_returns.std() * np.sqrt(252))
allsharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      374.254085
# PAULSON & CO.INC.              540.452680
# TIGER GLOBAL MANAGEMENT LLC    146.393799
# BERKSHIRE HATHAWAY INC         184.565829
# Algo 1                         156.501642
# Algo 2                         259.052500
# S&P 500                        383.090952
# 0                                0.876152
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
allsharpe_ratios.plot(kind='bar', title ='All Sharpe Ratios for all Portfolios Bar Plot')

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
